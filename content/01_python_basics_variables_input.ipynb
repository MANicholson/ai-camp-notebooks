# %% [markdown]
# # 🐍 Python Basics 1: Variables, Printing, Maths and Input
#
# Welcome to your first coding notebook.
#
# Today you will learn how to:
#
# - print messages
# - create variables
# - do maths with Python
# - ask the user for input
# - build a mini personal chatbot
#
# Run each code cell by clicking it and pressing **Shift + Enter**.

# %% [markdown]
# ## 1. Printing
#
# `print()` tells Python to show something on the screen.

# %%
print("Hello, AI Camp!")

# %% [markdown]
# ### Exercise 1
#
# Change the code so it prints your own name.

# %%
# Change this
print("My name is ...")

# %% [markdown]
# ### Exercise 2
#
# Make Python print three separate lines:
#
# 1. your name
# 2. your age
# 3. one thing you like

# %%
# Write your code here

# %% [markdown]
# ## 2. Variables
#
# A variable is like a labelled box. It stores information.

# %%
name = "Alice"
age = 14

print(name)
print(age)

# %% [markdown]
# ### Exercise 3
#
# Change the variables below so they describe you.

# %%
name = "Alice"
age = 14
favourite_food = "pizza"

print(name)
print(age)
print(favourite_food)

# %% [markdown]
# ### Exercise 4
#
# Create variables for:
#
# - your favourite animal
# - your favourite sport or hobby
# - your dream job
#
# Then print all three.

# %%
# Write your code here

# %% [markdown]
# ## 3. Strings
#
# Text in Python is called a **string**. Strings go inside quotation marks.

# %%
word1 = "machine"
word2 = "learning"

print(word1 + " " + word2)

# %% [markdown]
# ### Exercise 5
#
# Use variables to print this sentence:
#
# `I am learning Python!`

# %%
# Write your code here

# %% [markdown]
# ## 4. Numbers and maths

# %%
x = 10
y = 3

print(x + y)
print(x - y)
print(x * y)
print(x / y)

# %% [markdown]
# ### Exercise 6
#
# Create two number variables. Print:
#
# - their sum
# - their difference
# - their product
# - their average

# %%
# Write your code here

# %% [markdown]
# ### Exercise 7: Height calculator
#
# Store your height and a friend's height in centimetres. Calculate the average height.

# %%
# Example
my_height = 160
friend_height = 170

# Change the values and calculate the average
average_height = (my_height + friend_height) / 2
print(average_height)

# %% [markdown]
# ## 5. Updating variables
#
# Variables can change. This is useful for scores in games.

# %%
score = 0
score = score + 10
score = score + 5

print(score)

# %% [markdown]
# ### Exercise 8: Game score
#
# A player starts with 100 points.
#
# - They lose 20 points.
# - They gain 50 points.
# - They lose 5 points.
#
# Print the final score.

# %%
# Write your code here

# %% [markdown]
# ## 6. Input
#
# `input()` asks the user a question.

# %%
name = input("What is your name? ")
print("Hello", name)

# %% [markdown]
# ### Exercise 9
#
# Ask the user for their favourite colour. Then print a sentence using their answer.

# %%
# Write your code here

# %% [markdown]
# ### Exercise 10
#
# Ask the user for:
#
# - their name
# - their favourite food
# - their favourite animal
#
# Then print a short message about them.

# %%
# Write your code here

# %% [markdown]
# ## 7. Important: input gives text
#
# Even if the user types a number, Python treats it as text unless we convert it.

# %%
age_text = input("How old are you? ")
age = int(age_text)

print("Next year you will be", age + 1)

# %% [markdown]
# ### Exercise 11: Age in 10 years
#
# Ask the user for their age. Print how old they will be in 10 years.

# %%
# Write your code here

# %% [markdown]
# ### Exercise 12: Simple calculator
#
# Ask the user for two numbers. Print their sum.

# %%
# Write your code here

# %% [markdown]
# ## 🧠 Mini Challenge: Personal chatbot
#
# Build a chatbot that asks at least 4 questions and then prints a short funny description of the person.
#
# Example output:
#
# `Hello Martin! You are a pizza-loving football fan who wants to become an engineer.`

# %%
# Build your chatbot here

# %% [markdown]
# ## ⭐ Bonus Challenge
#
# Create a program that asks for the user's birth year and prints their approximate age.
#
# You can assume the current year is 2026.

# %%
# Bonus challenge
