# %% [markdown]
# # Rock, Paper, Scissors — Guided Python Challenge
#
# Today your goal is to **build your own Rock, Paper, Scissors game in Python**.
#
# You will not be given the full solution. Instead, each section gives you:
#
# - a small goal
# - a few hints
# - a code cell with `TODO` comments
# - quick checks to see whether your idea works
#
# By the end, you should have a game where:
#
# 1. the player chooses rock, paper, or scissors
# 2. the computer chooses randomly
# 3. Python decides who won
# 4. the game can keep score
# 5. optional: you add upgrades

# %% [markdown]
# ## Rules of the game
#
# Rock, Paper, Scissors has three possible moves:
#
# - **rock** beats **scissors**
# - **scissors** beats **paper**
# - **paper** beats **rock**
# - same move = draw
#
# Before coding, answer this in your head:
#
# > If the player chooses `rock`, what computer choice would make the player win?

# %% [markdown]
# ## Part 1 — Store the possible choices
#
# First, create a list containing the three possible choices.
#
# ### Hint
# A Python list looks like this:
#
# ```python
# my_list = ["first", "second", "third"]
# ```

# %%
# TODO: Create a list called choices containing "rock", "paper", and "scissors"

choices = []  # replace this with your list

print(choices)

# %% [markdown]
# ### Checkpoint
# Run the cell below. If your list is correct, it should print `3`.

# %%
print(len(choices))

# %% [markdown]
# ## Part 2 — Get the player's choice
#
# Now ask the player what they want to choose.
#
# ### Hint
# Use `input()` to ask a question.
#
# You may also want to use `.lower()` so that `Rock`, `ROCK`, and `rock` are treated the same.

# %%
# TODO: Ask the user to type rock, paper, or scissors
# Store their answer in a variable called player_choice

player_choice = ""  # replace this

print("You chose:", player_choice)

# %% [markdown]
# ## Part 3 — Check if the player's choice is valid
#
# The player should only be allowed to choose:
#
# - rock
# - paper
# - scissors
#
# If they type something else, print a warning message.
#
# ### Hint
# You can check whether something is inside a list using `in`:
#
# ```python
# if item in my_list:
#     print("This is allowed")
# ```
#
# You can also use `not in`.

# %%
# TODO: Check whether player_choice is valid
# If it is valid, print "Valid choice"
# Otherwise, print "Invalid choice"

# Write your if statement here

# %% [markdown]
# ## Part 4 — Make the computer choose randomly
#
# The computer should randomly choose rock, paper, or scissors.
#
# ### Hint
# First import the `random` module:
#
# ```python
# import random
# ```
#
# Then use:
#
# ```python
# random.choice(some_list)
# ```

# %%
# TODO: Import random
# TODO: Make the computer choose one item from choices
# Store it in a variable called computer_choice

computer_choice = ""  # replace this

print("Computer chose:", computer_choice)

# %% [markdown]
# ## Part 5 — Decide if it is a draw
#
# The easiest case is a draw.
#
# If the player and computer choose the same thing, nobody wins.
#
# ### Hint
# Use `==` to compare two values.

# %%
# TODO: Print "Draw!" if player_choice and computer_choice are the same

# Write your if statement here

# %% [markdown]
# ## Part 6 — Decide who wins
#
# Now comes the main logic.
#
# The player wins if:
#
# - player chooses rock AND computer chooses scissors
# - player chooses scissors AND computer chooses paper
# - player chooses paper AND computer chooses rock
#
# ### Hint
# You can combine conditions using `and` and `or`.
#
# Example structure:
#
# ```python
# if condition_1 or condition_2 or condition_3:
#     print("Player wins")
# ```
#
# You need to replace `condition_1`, `condition_2`, and `condition_3` with the actual game rules.

# %%
# TODO: Write an if / elif / else structure that decides the result
# Possible outputs:
# - "Draw!"
# - "You win!"
# - "Computer wins!"

# Write your code here

# %% [markdown]
# ## Part 7 — Put the game into a function
#
# At the moment, your code probably works once. But games are easier to reuse if we put the logic inside a function.
#
# Create a function called `play_round()`.
#
# When called, it should:
#
# 1. ask the player for a choice
# 2. make the computer choose randomly
# 3. print both choices
# 4. print the result
#
# ### Hint
# A function looks like this:
#
# ```python
# def function_name():
#     # code goes here
# ```
#
# Be careful with indentation.

# %%
def play_round():
    # TODO: Ask for player choice
    # TODO: Check if it is valid
    # TODO: Make computer choose randomly
    # TODO: Decide and print the result
    pass  # remove this when you add your own code

# Test your function by calling it once
play_round()

# %% [markdown]
# ## Part 8 — Return the result instead of only printing it
#
# To keep score, your function needs to give information back.
#
# Instead of only printing who won, make your function `return` one of these strings:
#
# - `"player"`
# - `"computer"`
# - `"draw"`
# - `"invalid"`
#
# ### Hint
# Returning a value looks like this:
#
# ```python
# return "player"
# ```
#
# Then you can store the result:
#
# ```python
# result = play_round()
# ```

# %%
def play_round():
    # TODO: Build your improved version here
    # It should return "player", "computer", "draw", or "invalid"
    pass

result = play_round()
print("Round result:", result)

# %% [markdown]
# ## Part 9 — Keep score
#
# Now create score variables:
#
# - `player_score`
# - `computer_score`
# - `draws`
#
# Play one round, then update the correct score.
#
# ### Hint
# To increase a score by 1:
#
# ```python
# score = score + 1
# ```
#
# or
#
# ```python
# score += 1
# ```

# %%
player_score = 0
computer_score = 0
draws = 0

# TODO: Play one round and store the result

# TODO: Update the correct score based on the result

print("Player:", player_score)
print("Computer:", computer_score)
print("Draws:", draws)

# %% [markdown]
# ## Part 10 — Play multiple rounds
#
# Now use a loop to play several rounds.
#
# Start with 3 rounds.
#
# ### Hint
# A `for` loop can repeat code a fixed number of times:
#
# ```python
# for i in range(3):
#     print("Round", i)
# ```
#
# Can you make it print `Round 1`, `Round 2`, and `Round 3` instead?

# %%
player_score = 0
computer_score = 0
draws = 0

# TODO: Use a for loop to play 3 rounds
# TODO: Update the score after each round

print("Final score:")
print("Player:", player_score)
print("Computer:", computer_score)
print("Draws:", draws)

# %% [markdown]
# ## Part 11 — Declare the final winner
#
# After all rounds are finished, print who won overall.
#
# ### Hint
# Compare `player_score` and `computer_score`.
#
# Possible final messages:
#
# - `You won the match!`
# - `The computer won the match!`
# - `The match was a draw!`

# %%
# TODO: Decide who won overall using player_score and computer_score

# Write your code here

# %% [markdown]
# # Extensions
#
# Choose one or more extensions if you finish early.
#
# ## Extension 1 — Best of 5
#
# Instead of exactly 3 rounds, play until either the player or computer reaches 3 wins.
#
# ### Hint
# A `while` loop may be useful.

# %%
# Extension 1 code here

# %% [markdown]
# ## Extension 2 — Let the player quit
#
# Allow the player to type `quit` to stop the game early.
#
# ### Hint
# Check the player's input before deciding the winner.

# %%
# Extension 2 code here

# %% [markdown]
# ## Extension 3 — Add emojis
#
# Make the game more fun by printing emojis:
#
# - rock = 🪨
# - paper = 📄
# - scissors = ✂️
#
# ### Hint
# A dictionary could help:
#
# ```python
# emojis = {
#     "rock": "🪨"
# }
# ```

# %%
# Extension 3 code here

# %% [markdown]
# ## Extension 4 — Add difficulty: computer uses strategy
#
# Instead of choosing completely randomly, make the computer more likely to choose the move that beats the player's previous move.
#
# Example:
#
# - If the player previously chose rock, the computer might choose paper next time.
#
# ### Think first
# What information does the computer need to remember from the previous round?

# %%
# Extension 4 code here

# %% [markdown]
# ## Extension 5 — Rock, Paper, Scissors, Lizard, Spock
#
# Add two extra moves:
#
# - lizard
# - spock
#
# You will need more rules.
#
# ### Hint
# Do not try to write everything at once. First update the list of choices, then add one rule at a time.

# %%
# Extension 5 code here

# %% [markdown]
# # Final reflection
#
# Answer these questions in a markdown cell or as comments:
#
# 1. What was the hardest part of the logic?
# 2. What bug did you find and fix?
# 3. What extension would you add if you had more time?
# 4. How could this game become an AI game?
