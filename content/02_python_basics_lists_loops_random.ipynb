# %% [markdown]
# # 🐍 Python Basics 2: Lists, Loops and Randomness
#
# Today you will learn how to:
#
# - store many things in a list
# - get items from a list
# - change lists
# - repeat code with loops
# - use randomness to make games

# %% [markdown]
# ## 1. Lists
#
# A list stores multiple values in one variable.

# %%
animals = ["cat", "dog", "rabbit"]
print(animals)

# %% [markdown]
# ### Exercise 1
#
# Create a list of five foods. Print the list.

# %%
# Write your code here

# %% [markdown]
# ## 2. Getting items from a list
#
# Python starts counting from **0**.

# %%
animals = ["cat", "dog", "rabbit"]

print(animals[0])
print(animals[1])
print(animals[2])

# %% [markdown]
# ### Exercise 2
#
# Create a list of five countries.
#
# Print:
#
# - the first country
# - the third country
# - the fifth country

# %%
# Write your code here

# %% [markdown]
# ## 3. Changing lists

# %%
animals = ["cat", "dog", "rabbit"]
animals[1] = "tiger"
print(animals)

# %% [markdown]
# ### Exercise 3
#
# Create a list of three school subjects. Replace one of them with another subject.

# %%
# Write your code here

# %% [markdown]
# ## 4. Adding to lists

# %%
animals = ["cat", "dog", "rabbit"]
animals.append("lion")
print(animals)

# %% [markdown]
# ### Exercise 4
#
# Create a list of three hobbies. Add two more hobbies using `.append()`.

# %%
# Write your code here

# %% [markdown]
# ## 5. Length of a list

# %%
animals = ["cat", "dog", "rabbit", "lion"]
print(len(animals))

# %% [markdown]
# ### Exercise 5
#
# Create a list of names of people in your group. Print how many people are in the group.

# %%
# Write your code here

# %% [markdown]
# ## 6. Loops
#
# A loop repeats code.

# %%
animals = ["cat", "dog", "rabbit"]

for animal in animals:
    print(animal)

# %% [markdown]
# ### Exercise 6
#
# Create a list of five foods. Use a loop to print each food.

# %%
# Write your code here

# %% [markdown]
# ### Exercise 7
#
# Use a loop to print this for each animal:
#
# `I like cats`
#
# or
#
# `I like dogs`

# %%
animals = ["cats", "dogs", "tigers"]

# Write your loop here

# %% [markdown]
# ## 7. Loops with numbers

# %%
for number in range(5):
    print(number)

# %% [markdown]
# ### Exercise 8
#
# Use `range()` to print the numbers from 0 to 9.

# %%
# Write your code here

# %% [markdown]
# ### Exercise 9
#
# Use a loop to print the 5 times table:
#
# 5, 10, 15, ..., 50

# %%
# Write your code here

# %% [markdown]
# ## 8. Random numbers

# %%
import random

number = random.randint(1, 6)
print(number)

# %% [markdown]
# ### Exercise 10
#
# Simulate rolling a dice 10 times.

# %%
# Write your code here

# %% [markdown]
# ## 9. Random choices from a list

# %%
import random

foods = ["pizza", "sushi", "pasta", "tacos"]
choice = random.choice(foods)
print(choice)

# %% [markdown]
# ### Exercise 11: Random team picker
#
# Create a list of names. Use `random.choice()` to choose one person.

# %%
# Write your code here

# %% [markdown]
# ## 🧠 Mini Challenge: Random compliment generator
#
# Make three lists:
#
# - names
# - positive adjectives
# - talents
#
# Randomly choose one from each list and print a sentence.
#
# Example:
#
# `Lina is amazingly creative at coding!`

# %%
# Build your compliment generator here

# %% [markdown]
# ## ⭐ Final Challenge: Guess the number
#
# Build a simple game:
#
# 1. Python chooses a random number from 1 to 10.
# 2. The player guesses.
# 3. Python says whether they are correct.
#
# Hint: you will need `input()`, `int()`, `random.randint()` and `if`. If you don't know `if` yet, ask your teacher!

# %%
# Guess the number game
